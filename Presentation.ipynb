# %% [markdown]
# # What is wrong with United States Schools?

# %% [markdown]
# Ariel Sim and Samantha Maillie

# %% [markdown]
# ## What made us ask this question? What are people saying?

# %% [markdown]
# 1. Frequently students feel unprepared coming from United States schools into College.
# 2. Compared to other countries the United States students are scoring lower on exams.
# 3. There is a wide learning gap between different schools.
# 4. Some schools focus on test scores too much. For example Sam's high school only allowed the lowest score to be 50%.
# 5. Charter schools are better than public schools.
# 6. Teachers are restricted too much in what they can teach.
# 7. Schools with large ethnic minority populations are discriminated against.
# 8. Schools from lower income areas do not have adequate funding.

# %% [markdown]
# ## Where do we begin?

# %% [markdown]
# Each state has a different school system. Our goal was to focus on one state to begin investigating a very broad question. We selected Massachussets. Here are some things to note:
#
# 1. Our data set is published on kaggle and was originally compiled from MA Department of Education Reports.
# 2. MA has a larger proportion of people who identify as white than the United States as a whole.
# 3. Hispanic Americans are the largest ethnic minority in both the Untied States and MA followed by African Americans.
# 4. MA has a smaller proportion of people below the poverty line than the United States as a whole.

# %% [markdown]
# ## Let's keep it brief. Today we will just look at variation in Math SAT scores.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pylab
import seaborn as sns

# %%
MASchools = pd.read_csv("MA_Public_Schools_2017.csv")

# %% [markdown]
# ## Comparing Ethnic Background  with Test Scores

# %%
sns.pairplot(x_vars=['% Hispanic'], y_vars=['Average SAT_Math'], data=MASchools, hue='School Type', size=9)
plt.xlabel('Percentage of Hispanic Students')
plt.ylabel('Average Math SAT Scores')
plt.title('Hispanic')
plt.show()

# %%
sns.pairplot(x_vars=['% African American'], y_vars=['Average SAT_Math'], data=MASchools, hue='School Type', size=9)
plt.xlabel('Percentage of African American Students')
plt.ylabel('Average Math SAT Scores')
plt.title('African American')
plt.show()

# %%
sns.pairplot(x_vars=['% Asian'], y_vars=['Average SAT_Math'], data=MASchools, hue='School Type', size=9)
plt.xlabel('Percentage of Asian Students')
plt.ylabel('Average Math SAT Scores')
plt.title('Asian')
plt.show()

# %%
sns.pairplot(x_vars=['% White'], y_vars=['Average SAT_Math'], data=MASchools, hue='School Type', size=9)
plt.xlabel('Percentage of White Students')
plt.ylabel('Average Math SAT Scores')
plt.title('White')
plt.show()

# %% [markdown]
# Here we began to question if we are looking at the best parameter? Is this a case of systematic discrimination by ethnicity? Is there a relation between schools with higher miniority populations and schools in lower income areas?

# %%
sns.pairplot(x_vars=['% Hispanic'], y_vars=['% Economically Disadvantaged'], data=MASchools, hue='School Type', size=9)
plt.xlabel('Percentage of Hispanic Students')
plt.ylabel('Percentage of Economically Disadvantaged Students')
plt.show()

# %%
sns.pairplot(x_vars=['% White'], y_vars=['% Economically Disadvantaged'], data=MASchools, hue='School Type', size=9)
plt.xlabel('Percentage of White Students')
plt.ylabel('Percentage of Economically Disadvantaged Students')
plt.show()

# %% [markdown]
# ## So what is the relationship between lower income schools and test scores?

# %%
sns.pairplot(x_vars=['% Economically Disadvantaged'], y_vars=['Average SAT_Math'], data=MASchools, hue='School Type', size=9)
plt.xlabel('Percentage of Economically Disadvantaged Students')
plt.ylabel('Average SAT Math Score')
plt.title('Lower Income Area Test Scores')
plt.show()

# %% [markdown]
# This is sadly linear. Our analysis begins to show a very strong relationship between these two variables. The variation in test scores is primarily able to be explained by the percentage of economically disadvantaged students.

# %% [markdown]
# ## Where to from here?

# %% [markdown]
# We still have a lot we are looking at here. We also ommitted alot to keep the presentation short today. One big thing is we use different merits of academic success in students such as:
# 1. Other SAT scores
# 2. AP Exam scores
# 3. College Attendance

# %% [markdown]
# ## Beyond the scope of this project:

# %% [markdown]
# 1. How does this look across the entire country?
# 2. Are there other merits of success? Is college really the ultimate merit of a successful primary school education?
# 3. Why are lower income areas preforming worse?
#     a. Insufficient breakfast and lunch options?
#     b. Lack of funding? What does that result in?
#     c. Are the best teachers drawn to "better" schools?

# %% [markdown]
# ## Don't lose hope though here is a list of organizations working towards a better system:

# %% [markdown]
# 1. http://www.roomtoread.org literacy and gender equality
# 2. http://www.fawe.org African American education advocacy
# 3. http://stand.org/national/about ending discrimination in education
# 4. http://www.collegepossible.org/ Getting low income students to college
# 5. There are even more! As we began to identify the problem we can solve it.
